# %%
import matplotlib.pyplot as plt
import numpy as np

#evenly sampled  time at 0.350s intervals
t = np.arange(0., 5, 0.350)

#red dashes, blue squares and green triangles
plt.plot(t, t,'r--', t, t**2,'bs', t, t**3,'g^')
plt.show()
